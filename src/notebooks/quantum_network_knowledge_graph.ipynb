# %% [markdown]
# #  Quantum network knowledge graphs
#
# El propósit de este documento es crear un pipelien de creación de un grafo de personas asociadas en la comunidad de comptuación cuántica, ya fuera pro mención o por perfilamiento.
#
# Nos interesa modelar el siguente grafo de conocimiento, el ecosistema de empresas e investigadores, así como las perosnas en el ecosistema que investigan, y que están en linkedin, si la idea es generar covnersación sobre quantum, la investigación, temas de investigación en común, deberían tener un mapa para poder orientar los esfuerzos.

# %%
import pandas as pd
from neo4j import GraphDatabase, Driver, Session
from pydantic import BaseModel
from contextlib import contextmanager
from typing import Optional, List, Dict, Any, Type

from langchain_ollama.chat_models import ChatOllama
from langchain_core.prompts import ChatPromptTemplate

from dotenv import load_dotenv, find_dotenv
import os


_ = load_dotenv(find_dotenv())
_
# Out:
# True

# %% [markdown]
# - Calificaremos algunas preguntas para darle peso a alguans relaciones y atibutos.
# - Interés principal en Computación Cuántica - (Seleccionar una o más): (Tags Que serán Sub Nodos)
# - ¿Ha trabajado previamente con tecnologías cuánticas?
# - ¿Qué espera obtener de este evento?:

# %%
def create_driver(uri: str, user: str, password: str) -> Driver:
    """
    Crea un driver de conexión a Neo4j
    
    Args:
        uri: URI de conexión (ej: "bolt://localhost:7687")
        user: Usuario de Neo4j
        password: Contraseña
        
    Returns:
        Driver de Neo4j
    """
    return GraphDatabase.driver(uri, auth=(user, password))


def close_driver(driver: Driver) -> None:
    """Cierra la conexión del driver"""
    driver.close()


@contextmanager
def get_session(driver: Driver):
    """
    Context manager para manejar sesiones de Neo4j
    
    Usage:
        with get_session(driver) as session:
            # usar session
    """
    session = driver.session()
    try:
        yield session
    finally:
        session.close()

# %%
driver = create_driver(
    uri=os.getenv("NEO4J_URI"),
    user=os.getenv("NEO4J_USER"),
    password=os.getenv("NEO4J_QUANTUM_NETWORK_AURA")
)

# %%
    
with get_session(driver) as session:
    result = session.run("""
    MATCH (n) RETURN n
    """)
    result.single()
# Out:
# ---------------------------------------------------------------------------
# AuthError                                 Traceback (most recent call last)
# Cell In[21], line 8
#       1 driver = create_driver(
#       2     uri=os.getenv("NEO4J_URI"),
#       3     user=os.getenv("NEO4J_USER"),
#       4     password=os.getenv("NEO4J_QUANTUM_NETWORK_AURA")
#       5 )
#       7 with get_session(driver) as session:
# ----> 8     result = session.run("""
#       9     MATCH (n) RETURN n
#      10     """)
#      11     result.single()
#
# File d:\projects\Quantum-Network-Knowledge-Graph\.venv\Lib\site-packages\neo4j\_sync\work\session.py:305, in Session.run(self, query, parameters, **kwargs)
#     302     self._auto_result._buffer_all()
#     304 if not self._connection:
# --> 305     self._connect(self._config.default_access_mode)
#     306     assert self._connection is not None
#     307 cx = self._connection
#
# File d:\projects\Quantum-Network-Knowledge-Graph\.venv\Lib\site-packages\neo4j\_sync\work\session.py:126, in Session._connect(self, access_mode, **acquire_kwargs)
#     124     access_mode = self._config.default_access_mode
#     125 try:
# --> 126     super()._connect(
#     127         access_mode, auth=self._config.auth, **acquire_kwargs
#     128     )
#     129 except asyncio.CancelledError:
#     130     self._handle_cancellation(message="_connect")
#
# File d:\projects\Quantum-Network-Knowledge-Graph\.venv\Lib\site-packages\neo4j\_sync\work\workspace.py:166, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     161 acquisition_deadline = acquisition_timeout_to_deadline(
#     162     acquisition_timeout
#     163 )
#     165 ssr_enabled = self._pool.ssr_enabled
# --> 166 target_db = self._get_routing_target_database(
#     167     acquire_auth,
#     168     ssr_enabled=ssr_enabled,
#     169     acquisition_deadline=acquisition_deadline,
#     170 )
#     171 acquire_kwargs_ = {
#     172     "access_mode": access_mode,
#     173     "timeout": acquisition_deadline,
#    (...)    178     "database_callback": self._make_db_resolution_callback(),
#     179 }
#     180 acquire_kwargs_.update(acquire_kwargs)
#
# File d:\projects\Quantum-Network-Knowledge-Graph\.venv\Lib\site-packages\neo4j\_sync\work\workspace.py:244, in Workspace._get_routing_target_database(self, acquire_auth, ssr_enabled, acquisition_deadline)
#     241         return AcquisitionDatabase(cached_db, guessed=True)
#     243 log.debug("[#0000]  _: <WORKSPACE> resolve home database")
# --> 244 self._pool.update_routing_table(
#     245     database=self._config.database,
#     246     imp_user=self._config.impersonated_user,
#     247     bookmarks=self._get_bookmarks(),
#     248     auth=acquire_auth,
#     249     acquisition_timeout=acquisition_deadline,
#     250     database_callback=self._make_db_resolution_callback(),
#     251 )
#     252 return AcquisitionDatabase(self._config.database)
#
# File d:\projects\Quantum-Network-Knowledge-Graph\.venv\Lib\site-packages\neo4j\_sync\io\_pool.py:1009, in Neo4jPool.update_routing_table(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback)
#    1002     existing_routers = {self.address}
#    1003     prefer_initial_routing_address = True
#    1005 if (
#    1006     prefer_initial_routing_address
#    1007     and
#    1008     # TODO: Test this state
# -> 1009     self._update_routing_table_from(
#    1010         self.address,
#    1011         database=database,
#    1012         imp_user=imp_user,
#    1013         bookmarks=bookmarks,
#    1014         auth=auth,
#    1015         acquisition_timeout=acquisition_timeout,
#    1016         database_callback=database_callback,
#    1017         ignored_errors=errors,
#    1018     )
#    1019 ):
#    1020     # Why is only the first initial routing address used?
#    1021     return
#    1022 if self._update_routing_table_from(
#    1023     *(existing_routers - {self.address}),
#    1024     database=database,
#    (...)   1030     ignored_errors=errors,
#    1031 ):
#
# File d:\projects\Quantum-Network-Knowledge-Graph\.venv\Lib\site-packages\neo4j\_sync\io\_pool.py:935, in Neo4jPool._update_routing_table_from(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback, ignored_errors, *routers)
#     931 for router in routers:
#     932     for address in NetworkUtil.resolve_address(
#     933         router, resolver=self.pool_config.resolver
#     934     ):
# --> 935         new_routing_table = self.fetch_routing_table(
#     936             address=address,
#     937             acquisition_timeout=acquisition_timeout,
#     938             database=database,
#     939             imp_user=imp_user,
#     940             bookmarks=bookmarks,
#     941             auth=auth,
#     942             ignored_errors=ignored_errors,
#     943         )
#     944         if new_routing_table is not None:
#     945             new_database = new_routing_table.database
#
# File d:\projects\Quantum-Network-Knowledge-Graph\.venv\Lib\site-packages\neo4j\_sync\io\_pool.py:833, in Neo4jPool.fetch_routing_table(self, address, acquisition_timeout, database, imp_user, bookmarks, auth, ignored_errors)
#     831 new_routing_info = None
#     832 try:
# --> 833     new_routing_info = self.fetch_routing_info(
#     834         address,
#     835         database,
#     836         imp_user,
#     837         bookmarks,
#     838         auth,
#     839         acquisition_timeout,
#     840     )
#     841 except Neo4jError as e:
#     842     # checks if the code is an error that is caused by the client. In
#     843     # this case there is no sense in trying to fetch a RT from another
#     844     # router. Hence, the driver should fail fast during discovery.
#     845     if e._is_fatal_during_discovery():
#
# File d:\projects\Quantum-Network-Knowledge-Graph\.venv\Lib\site-packages\neo4j\_sync\io\_pool.py:792, in Neo4jPool.fetch_routing_info(self, address, database, imp_user, bookmarks, auth, acquisition_timeout)
#     790     auth = copy(auth)
#     791     auth.force_auth = False
# --> 792 cx = self._acquire(address, auth, deadline, None)
#     793 try:
#     794     routing_table = cx.route(
#     795         database=database or self.workspace_config.database,
#     796         imp_user=imp_user or self.workspace_config.impersonated_user,
#     797         bookmarks=bookmarks,
#     798     )
#
# File d:\projects\Quantum-Network-Knowledge-Graph\.venv\Lib\site-packages\neo4j\_sync\io\_pool.py:418, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout, unprepared)
#     413             raise ConnectionAcquisitionTimeoutError(
#     414                 "failed to obtain a connection from the pool within "
#     415                 f"{deadline.original_timeout!r}s (timeout)"
#     416             )
#     417 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 418 return connection_creator()
#
# File d:\projects\Quantum-Network-Knowledge-Graph\.venv\Lib\site-packages\neo4j\_sync\io\_pool.py:231, in IOPool._acquire_new_later.<locals>.connection_creator()
#     229 try:
#     230     try:
# --> 231         connection = self.opener(
#     232             address, auth or self.pool_config.auth, deadline
#     233         )
#     234     except ServiceUnavailable:
#     235         self.deactivate(address)
#
# File d:\projects\Quantum-Network-Knowledge-Graph\.venv\Lib\site-packages\neo4j\_sync\io\_pool.py:711, in Neo4jPool.open.<locals>.opener(addr, auth_manager, deadline)
#     710 def opener(addr, auth_manager, deadline):
# --> 711     return Bolt.open(
#     712         addr,
#     713         auth_manager=auth_manager,
#     714         deadline=deadline,
#     715         routing_context=routing_context,
#     716         pool_config=pool_config,
#     717     )
#
# File d:\projects\Quantum-Network-Knowledge-Graph\.venv\Lib\site-packages\neo4j\_sync\io\_bolt.py:424, in Bolt.open(address, auth_manager, deadline, routing_context, pool_config)
#     422 connection.socket.set_write_deadline(deadline)
#     423 try:
# --> 424     connection.hello()
#     425 finally:
#     426     connection.socket.set_read_deadline(None)
#
# File d:\projects\Quantum-Network-Knowledge-Graph\.venv\Lib\site-packages\neo4j\_sync\io\_bolt6.py:185, in Bolt6x0.hello(self, dehydration_hooks, hydration_hooks)
#     183 self.logon(dehydration_hooks, hydration_hooks)
#     184 self.send_all()
# --> 185 self.fetch_all()
#
# File d:\projects\Quantum-Network-Knowledge-Graph\.venv\Lib\site-packages\neo4j\_sync\io\_bolt.py:881, in Bolt.fetch_all(self)
#     879 response = self.responses[0]
#     880 while not response.complete:
# --> 881     detail_delta, summary_delta = self.fetch_message()
#     882     detail_count += detail_delta
#     883     summary_count += summary_delta
#
# File d:\projects\Quantum-Network-Knowledge-Graph\.venv\Lib\site-packages\neo4j\_sync\io\_bolt.py:866, in Bolt.fetch_message(self)
#     862 # Receive exactly one message
#     863 tag, fields = self.inbox.pop(
#     864     hydration_hooks=self.responses[0].hydration_hooks
#     865 )
# --> 866 res = self._process_message(tag, fields)
#     867 self.idle_since = monotonic()
#     868 return res
#
# File d:\projects\Quantum-Network-Knowledge-Graph\.venv\Lib\site-packages\neo4j\_sync\io\_bolt6.py:548, in Bolt6x0._process_message(self, tag, fields)
#     546 self._enrich_error_diagnostic_record(summary_metadata)
#     547 try:
# --> 548     response.on_failure(summary_metadata or {})
#     549 except (ServiceUnavailable, DatabaseUnavailable):
#     550     if self.pool:
#
# File d:\projects\Quantum-Network-Knowledge-Graph\.venv\Lib\site-packages\neo4j\_sync\io\_common.py:303, in LogonResponse.on_failure(self, metadata)
#     301 handler = self.handlers.get("on_summary")
#     302 Util.callback(handler)
# --> 303 raise self._hydrate_error(metadata)
#
# AuthError: {neo4j_code: Neo.ClientError.Security.Unauthorized} {message: The client is unauthorized due to authentication failure.} {gql_status: 42NFF} {gql_status_description: error: syntax error or access rule violation - permission/access denied. Access denied, see the security logs for details.}

# %%
def data_enhancer():
    '''
    Esta función tiene como propósito crear un LLM que puede extraer de un determinado texto, de 


    '''
    llm = ChatOllama(
        model="llama3.2:3b",
        base_url="http://localhost:11434",
        temperature=0.0
    )

    return llm

llm = data_enhancer()
llm.invoke("1+1")
# Out:
# AIMessage(content='1 + 1 = 2', additional_kwargs={}, response_metadata={'model': 'llama3.2:3b', 'created_at': '2025-11-16T21:25:27.1896229Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5045879500, 'load_duration': 4835097500, 'prompt_eval_count': 28, 'prompt_eval_duration': 40363600, 'eval_count': 8, 'eval_duration': 148681200, 'logprobs': None, 'model_name': 'llama3.2:3b', 'model_provider': 'ollama'}, id='lc_run--422de324-3e67-4e44-8add-e58a7f9fe7f4-0', usage_metadata={'input_tokens': 28, 'output_tokens': 8, 'total_tokens': 36})

# %%
'''

UNWIND rows
MERGE (p:Person)
ON CREATE SET
    p.name = rows.name
    p.location = rows.location
    p.industry = rows.industry
    p.interests = rows.interests
    P.linkedin_url = rows.linkedin_url

MERGE (o:Organization)
ON CREATE SET
    o.name = o.organization

WITH p, o
MERGE (p)-[:WORKS_AT]->(o)

MERGE (d:Domain)
ON CREATE SET
    i.name = rows.domain
MERGE (p)-[:HAS_INTEREST]->(d)




'''

# %%
def normalize_column_names(df: pd.DataFrame) -> pd.DataFrame:
    """
    Normaliza los nombres de columnas del CSV a nombres más manejables.
    
    Mapeo:
    - 'Nombre completo' -> 'name'
    - 'Correo electrónico' -> 'email'
    - 'Organización / Empresa' -> 'organization'
    - 'Cargo / Rol' -> 'role'
    - 'Sector al que pertenece su organización' -> 'industry_sector'
    - 'Interés principal en Computación Cuántica - (Seleccionar una o más)' -> 'interests'
    - '¿Ha trabajado previamente con tecnologías cuánticas?' -> 'quantum_experience'
    - '¿Qué espera obtener de este evento?' -> 'event_expectations'
    - 'LinkedIn' -> 'linkedin_url'
    
    Args:
        df: DataFrame con columnas originales
        
    Returns:
        DataFrame con columnas normalizadas
    """
    column_mapping = {
        'Nombre completo': 'name',
        'Correo electrónico': 'email',
        'Organización / Empresa': 'organization',
        'Cargo / Rol': 'role',
        'Sector al que pertenece su organización': 'industry_sector',
        'Interés principal en Computación Cuántica - (Seleccionar una o más)': 'interests',
        '¿Ha trabajado previamente con tecnologías cuánticas?': 'quantum_experience',
        '¿Qué espera obtener de este evento?': 'event_expectations',
        'LinkedIn': 'linkedin_url',
        'Timestamp': 'timestamp'  # Mantener timestamp para referencia
    }
    
    # Renombrar solo las columnas que existen
    df_normalized = df.rename(columns={k: v for k, v in column_mapping.items() if k in df.columns})
    
    return df_normalized

# %%
def clean_text(value: Any) -> Optional[str]:
    """
    Limpia valores de texto: elimina espacios extra, convierte a string,
    maneja NaN y valores vacíos.
    
    Args:
        value: Valor a limpiar
        
    Returns:
        String limpio o None si está vacío
    """
    if pd.isna(value) or value == '':
        return None
    
    # Convertir a string y limpiar
    text = str(value).strip()
    
    # Si después de limpiar está vacío, retornar None
    if text == '' or text.lower() == 'nan':
        return None

# %%
dataframe = pd.read_csv('../data/quantum_network.csv')
dataframe.head()
# Out:
#   Timestamp     Nombre completo        Correo electrónico  \
# 0    online      Federico Holik  holik@fisica.unlp.edu.ar
# 1    online      Mariano Caruso       mcaruso@fidesol.org
# 2       NaN      Tomás Tagliani      tomas@falcondale.pro
# 3       NaN         Julio Cella       Julio.Cella@ibm.com
# 4       NaN  Victoria Dominguez       marketing@qnow.tech
#
#   Organización / Empresa                Cargo / Rol  \
# 0            UNLP - IFLP               Investigador
# 1                FIDESOL  Investigador & Desarrollo
# 2             Falcondale                    Founder
# 3                    IBM    Security Client Leader
# 4                   QNOW                  Marketing
#
#   Sector al que pertenece su organización  \
# 0                Academia / Investigación
# 1             Industria / Empresa privada
# 2                Startup / Emprendimiento
# 3             Industria / Empresa privada
# 4                Startup / Emprendimiento
#
#   Interés principal en Computación Cuántica - (Seleccionar una o más)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Ha trabajado previamente con tecnologías cuánticas?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Qué espera obtener de este evento?  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   Preferencia de comida (para el lunch de cortesía)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   ¿Desea recibir novedades e invitaciones a futuros eventos de IBM y QNOW?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Email confirmación LinkedIn  Column 12
# 0                NaN      NaN        NaN
# 1                NaN      NaN        NaN
# 2                NaN      NaN        NaN
# 3                NaN      NaN        NaN
# 4                NaN      NaN        NaN

# %%
# PERSON NODE
# Nombre completo --> name
# Correo electrónico-->email
# ¿Ha trabajado previamente con tecnologías cuánticas?
# Cargo / Rol --> role
# LinkedIn --> linkedin_url

# DOMAIN
# Interés principal en Computación Cuántica - (Seleccionar una o más)


# ORGANIZATION NODE
# Organización / Empresa --> organtization
# Sector al que pertenece su organización --> industry_sector
